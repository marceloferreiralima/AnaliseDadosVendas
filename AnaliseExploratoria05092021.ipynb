# %%
import pandas as pd
import matplotlib.pyplot as plt
plt.style.use('seaborn')

# %%
#upload de arquivos do google colab
from google.colab import files
arq = files.upload()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-2-2bde6f6a0c8c> in <module>
#       1 #upload de arquivos do google colab
# ----> 2 from google.colab import files
#       3 arq = files.upload()
#
# ModuleNotFoundError: No module named 'google'

# %%
df = pd.read_excel('Financial Sample.xlsx')

# %%
df.head()
# Out:
#       Segment  Country    Product Discount Band  Units Sold  \
# 0  Government   Canada  Carretera          None      1618.5
# 1  Government  Germany  Carretera          None      1321.0
# 2   Midmarket   France  Carretera          None      2178.0
# 3   Midmarket  Germany  Carretera          None       888.0
# 4   Midmarket   Mexico  Carretera          None      2470.0
#
#    Manufacturing Price  Sale Price  Gross Sales  Discounts    Sales     COGS  \
# 0                    3          20      32370.0        0.0  32370.0  16185.0
# 1                    3          20      26420.0        0.0  26420.0  13210.0
# 2                    3          15      32670.0        0.0  32670.0  21780.0
# 3                    3          15      13320.0        0.0  13320.0   8880.0
# 4                    3          15      37050.0        0.0  37050.0  24700.0
#
#     Profit       Date  Month Number Month Name  Year
# 0  16185.0 2014-01-01             1    January  2014
# ...

# %%
df.shape
# Out:
# (700, 16)

# %%
df.dtypes
# Out:
# Segment                        object
# Country                        object
# Product                        object
# Discount Band                  object
# Units Sold                    float64
# Manufacturing Price             int64
# Sale Price                      int64
# Gross Sales                   float64
# Discounts                     float64
#  Sales                        float64
# COGS                          float64
# Profit                        float64
# Date                   datetime64[ns]
# Month Number                    int64
# Month Name                     object
# Year                            int64
# dtype: object

# %%
 df[' Sales'].sum()
# Out:
# 118726350.25999999

# %%
df['Gross Sales'].sum()
# Out:
# 127931598.5

# %%
df['custo'] = df['Units Sold'].mul(df['Sale Price'])

# %%
df.sample(5)
# Out:
#               Segment                   Country    Product Discount Band  \
# 148  Channel Partners                    Canada  Carretera           Low
# 80   Channel Partners                   Germany      Paseo           Low
# 356    Small Business  United States of America   Amarilla        Medium
# 91         Enterprise                    France        VTT           Low
# 186    Small Business                   Germany    Montana           Low
#
#      Units Sold  Manufacturing Price  Sale Price  Gross Sales  Discounts  \
# 148       908.0                    3          12      10896.0     326.88
# 80        766.0                   10          12       9192.0      91.92
# 356      1372.0                  260         300     411600.0   28812.00
# 91        787.0                  250         125      98375.0     983.75
# 186      2021.0                    5         300     606300.0   24252.00
#
#          Sales      COGS    Profit       Date  Month Number Month Name  Year  \
# ...

# %%
round(df['custo'].sum(),2)
# Out:
# 127931598.5

# %%
df['lucro'] = df['Gross Sales'] - df[' Sales']

# %%
df.sample(5)
# Out:
#             Segment                   Country   Product Discount Band  \
# 211       Midmarket  United States of America  Amarilla           Low
# 239  Small Business                    Mexico     Paseo        Medium
# 421      Enterprise  United States of America     Paseo        Medium
# 528      Government                    Canada       VTT          High
# 589      Government                   Germany     Paseo          High
#
#      Units Sold  Manufacturing Price  Sale Price  Gross Sales  Discounts  \
# 211       671.0                  260          15      10065.0     402.60
# 239      1607.0                   10         300     482100.0   24105.00
# 421      2797.0                   10         125     349625.0   31466.25
# 528      2935.0                  250          20      58700.0    6457.00
# 589      2708.0                   10          20      54160.0    7040.80
#
#          Sales      COGS    Profit       Date  Month Number Month Name  Year  \
# ...

# %%
df.lucro.sum()
# Out:
# 9205248.24

# %%
df['tempoenvio'] = df['Date'] - df['Date'].min()

# %%
df.sample(5)
# Out:
#             Segment                   Country    Product Discount Band  \
# 101      Government                    France  Carretera           Low
# 651  Small Business                   Germany       Velo          High
# 82       Government                    France      Paseo           Low
# 113      Enterprise                   Germany      Paseo           Low
# 479      Government  United States of America        VTT          High
#
#      Units Sold  Manufacturing Price  Sale Price  Gross Sales  Discounts  \
# 101      2145.0                    3           7      15015.0      300.3
# 651      2536.0                  120         300     760800.0   106512.0
# 82       2155.0                   10         350     754250.0     7542.5
# 113       809.0                   10         125     101125.0     2022.5
# 479      2807.0                  250         350     982450.0    98245.0
#
#         Sales      COGS    Profit       Date  Month Number Month Name  Year  \
# ...

# %%
df['tempoenvio2'] = (df['Date'] - df['Date'].min()).dt.days

# %%
df.sample(5)
# Out:
#               Segment                   Country    Product Discount Band  \
# 375        Government  United States of America      Paseo        Medium
# 623  Channel Partners                    France   Amarilla          High
# 114        Enterprise                    Mexico      Paseo           Low
# 626        Enterprise                    France  Carretera          High
# 358        Government  United States of America    Montana        Medium
#
#      Units Sold  Manufacturing Price  Sale Price  Gross Sales  Discounts  \
# 375       678.0                   10           7       4746.0     379.68
# 623      1393.0                  260          12      16716.0    2340.24
# 114      2145.0                   10         125     268125.0    5362.50
# 626      1023.0                    3         125     127875.0   17902.50
# 358      1282.0                    5          20      25640.0    2051.20
#
#          Sales      COGS    Profit       Date  Month Number Month Name  Year  \
# ...

# %%
df.tempoenvio2.dtypes
# Out:
# dtype('int64')

# %%
df.dtypes
# Out:
# Segment                         object
# Country                         object
# Product                         object
# Discount Band                   object
# Units Sold                     float64
# Manufacturing Price              int64
# Sale Price                       int64
# Gross Sales                    float64
# Discounts                      float64
#  Sales                         float64
# COGS                           float64
# Profit                         float64
# Date                    datetime64[ns]
# Month Number                     int64
# Month Name                      object
# Year                             int64
# custo                          float64
# lucro                          float64
# tempoenvio             timedelta64[ns]
# tempoenvio2                      int64
# dtype: object

# %%
df.sample(5)
# Out:
#               Segment                   Country    Product Discount Band  \
# 600        Government                    France       Velo          High
# 358        Government  United States of America    Montana        Medium
# 100    Small Business                   Germany  Carretera           Low
# 448         Midmarket                    Mexico       Velo        Medium
# 418  Channel Partners                    Mexico      Paseo        Medium
#
#      Units Sold  Manufacturing Price  Sale Price  Gross Sales  Discounts  \
# 600      1190.0                  120           7       8330.0    1082.90
# 358      1282.0                    5          20      25640.0    2051.20
# 100       214.0                    3         300      64200.0    1284.00
# 448      2628.0                  120          15      39420.0    3547.80
# 418       367.0                   10          12       4404.0     396.36
#
#         Sales     COGS    Profit       Date  Month Number Month Name  Year  \
# ...

# %%
df['Discount Band'].unique()
# Out:
# array(['None', 'Low', 'Medium', 'High'], dtype=object)

# %%
df.isnull().sum()
# Out:
# Segment                0
# Country                0
# Product                0
# Discount Band          0
# Units Sold             0
# Manufacturing Price    0
# Sale Price             0
# Gross Sales            0
# Discounts              0
#  Sales                 0
# COGS                   0
# Profit                 0
# Date                   0
# Month Number           0
# Month Name             0
# Year                   0
# custo                  0
# lucro                  0
# tempoenvio             0
# tempoenvio2            0
# dtype: int64

# %%
df.sample(5)
# Out:
#             Segment  Country   Product Discount Band  Units Sold  \
# 416  Small Business   Canada     Paseo        Medium      1094.0
# 88       Government  Germany       VTT           Low       263.0
# 124      Government  Germany      Velo           Low      2966.0
# 324      Government   Canada       VTT        Medium      1582.0
# 269      Government   Canada  Amarilla        Medium       552.0
#
#      Manufacturing Price  Sale Price  Gross Sales  Discounts       Sales  \
# 416                   10         300     328200.0   29538.00   298662.00
# 88                   250           7       1841.0      18.41     1822.59
# 124                  120         350    1038100.0   20762.00  1017338.00
# 324                  250           7      11074.0     775.18    10298.82
# 269                  260         350     193200.0    9660.00   183540.00
#
#          COGS     Profit       Date  Month Number Month Name  Year      custo  \
# ...

# %%
df.groupby("Discount Band")["tempoenvio2"].mean()
# Out:
# Discount Band
# High      239.959184
# Low       239.287500
# Medium    238.694215
# None      246.981132
# Name: tempoenvio2, dtype: float64

# %%
df.Country.unique()
# Out:
# array(['Canada', 'Germany', 'France', 'Mexico',
#        'United States of America'], dtype=object)

# %%
df.groupby('Country')['custo'].mean()
# Out:
# Country
# Canada                      192372.596429
# France                      186297.675000
# Germany                     178010.482143
# Mexico                      162335.250000
# United States of America    194781.128571
# Name: custo, dtype: float64

# %%
df.isnull().sum()
# Out:
# Segment                0
# Country                0
# Product                0
# Discount Band          0
# Units Sold             0
# Manufacturing Price    0
# Sale Price             0
# Gross Sales            0
# Discounts              0
#  Sales                 0
# COGS                   0
# Profit                 0
# Date                   0
# Month Number           0
# Month Name             0
# Year                   0
# custo                  0
# lucro                  0
# tempoenvio             0
# tempoenvio2            0
# dtype: int64

# %%
df.groupby([df['Date'].dt.year, 'Country'])['lucro'].sum()
# Out:
# Date  Country
# 2013  Canada                       379497.220
#       France                       448087.830
#       Germany                      402529.530
#       Mexico                       396479.740
#       United States of America     518937.170
# 2014  Canada                      1665011.395
#       France                      1279414.390
#       Germany                     1013597.150
#       Mexico                      1381103.150
#       United States of America    1720590.665
# Name: lucro, dtype: float64

# %%
pd.options.display.float_format = '{:20,.2f}'.format

# %%
df.groupby([df['Date'].dt.year, 'Country'])['lucro'].sum()
# Out:
# Date  Country
# 2013  Canada                               379,497.22
#       France                               448,087.83
#       Germany                              402,529.53
#       Mexico                               396,479.74
#       United States of America             518,937.17
# 2014  Canada                             1,665,011.39
#       France                             1,279,414.39
#       Germany                            1,013,597.15
#       Mexico                             1,381,103.15
#       United States of America           1,720,590.66
# Name: lucro, dtype: float64

# %%
lucroano = df.groupby([df['Date'].dt.year, 'Country'])['lucro'].sum().reset_index()

# %%
lucroano
# Out:
#    Date                   Country                lucro
# 0  2013                    Canada           379,497.22
# 1  2013                    France           448,087.83
# 2  2013                   Germany           402,529.53
# 3  2013                    Mexico           396,479.74
# 4  2013  United States of America           518,937.17
# 5  2014                    Canada         1,665,011.39
# 6  2014                    France         1,279,414.39
# 7  2014                   Germany         1,013,597.15
# 8  2014                    Mexico         1,381,103.15
# 9  2014  United States of America         1,720,590.66

# %%
df.sample(5)
# Out:
#               Segment                   Country    Product Discount Band  \
# 59         Government                    Mexico  Carretera           Low
# 44         Government                    Canada        VTT          None
# 420  Channel Partners                   Germany      Paseo        Medium
# 524        Government                    Mexico       Velo          High
# 241    Small Business  United States of America      Paseo        Medium
#
#               Units Sold  Manufacturing Price  Sale Price  \
# 59              1,210.00                    3         350
# 44              1,817.00                  250          20
# 420             1,775.00                   10          12
# 524               344.00                  120         350
# 241               991.00                   10         300
#
#              Gross Sales            Discounts                Sales  \
# 59            423,500.00             4,235.00           419,265.00
# ...

# %%
df.groupby('Product')['Manufacturing Price'].sum().sort_values(ascending=False)
# Out:
# Product
# VTT          27250
# Amarilla     24440
# Velo         13080
# Paseo         2020
# Montana        465
# Carretera      279
# Name: Manufacturing Price, dtype: int64

# %%
df.groupby('Product')['Manufacturing Price'].sum().sort_values(ascending=False).plot.barh(title='total produtos')
plt.xlabel('total')
plt.ylabel('produto')
# Out:
# Text(0, 0.5, 'produto')

# %%
df.sample(5)
# Out:
#         Segment                   Country    Product Discount Band  \
# 599  Government                    Canada       Velo          High
# 388  Government                    France        VTT        Medium
# 335   Midmarket                    France      Paseo        Medium
# 537  Enterprise                    Canada  Carretera          High
# 141  Government  United States of America   Amarilla           Low
#
#               Units Sold  Manufacturing Price  Sale Price  \
# 599             2,632.00                  120         350
# 388               574.50                  250         350
# 335             2,101.00                   10          15
# 537             2,416.00                    3         125
# 141             1,236.00                  260          20
#
#              Gross Sales            Discounts                Sales  \
# 599           921,200.00           119,756.00           801,444.00
# 388           201,075.00            16,086.00           184,989.00
# ...

# %%
df.groupby(df['Date'].dt.year)['lucro'].sum().plot.bar(title='lucro por ano')
plt.xlabel('ano')
plt.ylabel('receita')
# Out:
# Text(0, 0.5, 'receita')

# %%
df2014 = df[df['Date'].dt.year == 2014]

# %%
df2014.head()
# Out:
#       Segment  Country    Product Discount Band           Units Sold  \
# 0  Government   Canada  Carretera          None             1,618.50
# 1  Government  Germany  Carretera          None             1,321.00
# 2   Midmarket   France  Carretera          None             2,178.00
# 3   Midmarket  Germany  Carretera          None               888.00
# 4   Midmarket   Mexico  Carretera          None             2,470.00
#
#    Manufacturing Price  Sale Price          Gross Sales            Discounts  \
# 0                    3          20            32,370.00                 0.00
# 1                    3          20            26,420.00                 0.00
# 2                    3          15            32,670.00                 0.00
# 3                    3          15            13,320.00                 0.00
# 4                    3          15            37,050.00                 0.00
#
#                  Sales                 COGS               Profit       Date  \
# ...

# %%
#minuto 20:20 da aula de análise exploratória

# %%
df2014.groupby(df2014['Month Number'])['lucro'].sum()
# Out:
# Month Number
# 1              699,641.82
# 2              401,669.61
# 3              537,166.13
# 4              464,617.43
# 5              557,699.94
# 6              750,078.18
# 7              730,107.32
# 8              461,336.58
# 9              446,619.76
# 10             937,604.08
# 11             563,695.80
# 12             509,480.10
# Name: lucro, dtype: float64

# %%
df2014.groupby(df2014['Month Number'])['lucro'].sum().plot(title='Lucro x mes')
plt.xlabel('Mês')
plt.ylabel('Lucro')
# Out:
# Text(0, 0.5, 'Lucro')

# %%
df2014.groupby(df2014['Product'])['lucro'].sum().plot(title='Lucro x produto')
plt.xlabel('Produto')
plt.ylabel('Lucro')
plt.xticks(rotation='horizontal');

# %%
df2014.groupby(df2014['Product'])['lucro'].sum().plot.bar(title='Lucro x produto')
plt.xlabel('Produto')
plt.ylabel('Lucro')
plt.xticks(rotation='horizontal');

# %%
df['tempoenvio2'].describe()
# Out:
# count                 700.00
# mean                  239.90
# std                   147.14
# min                     0.00
# 25%                   114.25
# 50%                   257.50
# 75%                   372.50
# max                   456.00
# Name: tempoenvio2, dtype: float64

# %%
plt.boxplot(df['tempoenvio2']);

# %%
plt.hist(df['tempoenvio2']);

# %%
df['tempoenvio2'].min()
# Out:
# 0

# %%
df['tempoenvio2'].max()
# Out:
# 456

# %%
df[df['tempoenvio2']==456]
# Out:
#               Segment                   Country    Product Discount Band  \
# 5          Government                   Germany  Carretera          None
# 15          Midmarket  United States of America    Montana          None
# 29         Government                    Canada      Paseo          None
# 30         Government                   Germany      Paseo          None
# 44         Government                    Canada        VTT          None
# ..                ...                       ...        ...           ...
# 637         Midmarket                    Canada    Montana          High
# 680  Channel Partners  United States of America      Paseo          High
# 681        Government                    France      Paseo          High
# 687  Channel Partners  United States of America       Velo          High
# 694        Government                    France        VTT          High
#
#               Units Sold  Manufacturing Price  Sale Price  \
# ...

# %%
df.to_csv('df_vendas_novo.csv', index=False)
